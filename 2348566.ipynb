# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikbanerjee/ML_Lab/blob/main/2348566.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import os
# import platform
# import psutil
# import socket
# import multiprocessing
# import time
# from datetime import datetime

# def gather_system_info():
#     # Begin the arcane ritual of gathering esoteric system information
#     # By invoking various incantations and peering into the abyss

#     # Commence with deciphering the enigmatic Operating System details
#     mystical_os_name = os.name
#     cryptic_platform = platform.system()
#     cryptic_release_version = platform.release()

#     # Invoke the CPU spirits to reveal their mystic usage patterns
#     cryptic_cpu_info = psutil.cpu_percent(interval=1, percpu=True)

#     # Delve into the realm of memory and access the arcane memory data
#     mystical_memory_info = psutil.virtual_memory()
#     arcane_total_memory = mystical_memory_info.total
#     arcane_available_memory = mystical_memory_info.available

#     # Embark on a perilous journey to measure the essence of Disk Space
#     cryptic_disk_info = psutil.disk_usage('/')
#     mysterious_total_space = cryptic_disk_info.total
#     enigmatic_used_space = cryptic_disk_info.used
#     cryptic_free_space = cryptic_disk_info.free

#     # Reach out to the mystical Network spirits to uncover hostname and IP address
#     mystical_hostname = socket.gethostname()
#     arcane_ip_address = socket.gethostbyname(mystical_hostname)

#     # Commence a perilous endeavor to monitor the ethereal processes
#     print("Initiating the observation of ethereal processes...")
#     for spectral_process in psutil.process_iter(['pid', 'name']):
#         spectral_pid = spectral_process.info['pid']
#         spectral_name = spectral_process.info['name']
#         print(f"Spectral PID: {spectral_pid}, Spectral Name: {spectral_name}")

# if __name__ == '__main__':
#     # Prepare the summoning circle for a separate, parallel dimension
#     parallel_realm_gates = multiprocessing.Process(target=gather_system_info)

#     # Open the gates and start the mysterious ritual in the background
#     parallel_realm_gates.start()

#     # Meanwhile, in the earthly realm, print numbers from 1 to 10 (big size) every second
#     for i in range(1, 11):
#         print(f"Number {i} (big size)")
#         time.sleep(1)

#     # Obtain the current system date and time
#     current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     print(f"System Date and Time: {current_datetime}")

#     # Display the final message
#     print("BackGround Record Starts..ALL THE BEST….")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/Iris.csv")

# %%
data.shape
# Out:
# (150, 6)

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df1=data

# %%
plt.figure(figsize=(6, 6))
plt.scatter(df1['SepalLengthCm'], df1['Species'], alpha=0.5, color='green')
plt.xlabel("Sepal Length")
plt.ylabel("Species")
plt.title("Scatterplot : Species vs Sepal Length")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(df1['SepalWidthCm'], df1['Species'], alpha=0.5, color='blue')
plt.xlabel("Sepal Width")
plt.ylabel("Species")
plt.title("Scatterplot : Species vs Sepal Width")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(df1['PetalLengthCm'], df1['Species'], alpha=0.5, color='brown')
plt.xlabel("Petal Length")
plt.ylabel("Species")
plt.title("Scatterplot : Species vs Petal Length")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(df1['PetalWidthCm'], df1['Species'], alpha=0.5, color='purple')
plt.xlabel("Petal Width")
plt.ylabel("Species")
plt.title("Scatterplot : Species vs Petal Width")
plt.grid(True)
plt.show()

# %%
df1=df1.drop('Id',axis=1)
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.model_selection import train_test_split
X = df1.drop('Species', axis=1)
Y = df1['Species']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=33)
X_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 98             5.1           2.5            3.0           1.1
# 11             4.8           3.4            1.6           0.2
# 131            7.9           3.8            6.4           2.0
# 39             5.1           3.4            1.5           0.2
# 21             5.1           3.7            1.5           0.4

# %%
Y_train.head()
# Out:
# 98     Iris-versicolor
# 11         Iris-setosa
# 131     Iris-virginica
# 39         Iris-setosa
# 21         Iris-setosa
# Name: Species, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000, random_state=42)
log_reg.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
# Calculate the confusion matrix
conf_matrix = confusion_matrix(Y_test, Y_pred)
# Create a heatmap to visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='magma', cbar=False,linewidths=5)

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Predictions - Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
# Make predictions on the test data
Y_pred = log_reg.predict(X_test)
# Calculate Accuracy
accuracy = accuracy_score(Y_test, Y_pred)
# Calculate Precision
precision = precision_score(Y_test, Y_pred,average='micro')
# Calculate Recall
recall = recall_score(Y_test, Y_pred,average='micro')
# Calculate F1-score
f1 = f1_score(Y_test, Y_pred,average='micro')


print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
# Out:
# Accuracy: 0.93
# Precision: 0.93
# Recall: 0.93
# F1-score: 0.93

# %%
from sklearn.metrics import roc_curve, roc_auc_score
Y_pred_proba = log_reg.predict_proba(X_test)

fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_proba[:,1],pos_label='binary')


plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

z = np.linspace(-7, 7, 200)

sigmoid_values = sigmoid(z)

plt.figure(figsize=(8, 6))
plt.plot(z, sigmoid_values, color='b', lw=2, label='Sigmoid Curve')
plt.xlabel('Input(z)')
plt.ylabel('Sigmoid Output (z)')
plt.title('Sigmoid (Logistic) Curve')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

grid_search = GridSearchCV(log_reg, param_grid, cv=5, scoring='accuracy')

grid_search.fit(X_train, Y_train)

best_C = grid_search.best_params_['C']

print(f"Best 'C' Hyperparameter: {best_C}")
# Out:
# Best 'C' Hyperparameter: 10

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

coefficients = log_reg.coef_

avg_importance = np.mean(np.abs(coefficients), axis=0)
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': avg_importance})
feature_importance = feature_importance.sort_values('Importance', ascending=True)
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6),color='lightgreen')
plt.title("Feature Significance")
plt.show()

# %% [markdown]
# Petal Length is the most important feature among all the features
