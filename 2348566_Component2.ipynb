# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikbanerjee/ML_Lab/blob/main/2348566_Component2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/content/2015.csv')

# %%
data.shape
# Out:
# (158, 12)

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
bins = [0,4,5.5,8]
bin_labels=['Low Happiness','Medium Happiness','High Happiness']
happiness_count=pd.cut(data['Happiness Score'],bins=bins,right=False).value_counts().sort_index()
plt.bar(bin_labels,happiness_count,color=['lightgreen','lightblue','yellow'])
plt.show()

# %%
data_encoded=pd.get_dummies(data,columns=['Region'])

# %%
data_encoded.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Standard Error  \
# 0  Switzerland               1            7.587         0.03411
# 1      Iceland               2            7.561         0.04884
# 2      Denmark               3            7.527         0.03328
# 3       Norway               4            7.522         0.03880
# 4       Canada               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  ...  \
# 0                        0.41978     0.29678  ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
df=pd.DataFrame
scaler=MinMaxScaler()
df=scaler.fit_transform(data_encoded.iloc[:,4:6])
df.reshape(-1,1)
# Out:
# array([[0.82613197],
#        [0.96240274],
#        [0.77041209],
#        [1.        ],
#        [0.78411282],
#        [0.97029731],
#        [0.86309911],
#        [0.94916668],
#        [0.78459199],
#        [0.94321902],
#        [0.76327185],
#        [0.94011681],
#        [0.78645544],
#        [0.91295294],
#        [0.7877983 ],
#        [0.91929997],
#        [0.73956768],
#        [0.94112236],
#        [0.78890453],
#        [0.93367707],
#        [0.72678388],
#        [0.8728454 ],
#        [0.56540978],
#        [0.88279384],
#        [0.79106376],
#        [0.92498378],
#        [0.60371979],
#        [0.65218259],
#        [0.82494883],
#        [0.88937621],
#        [0.58047113],
#        [0.87922096],
#        [0.92516061],
#        [0.86977885],
#        [0.79031247],
#        [0.97664435],
#        [0.77366572],
#        [0.91686813],
#        [0.84432863],
#        [0.80282835],
#        [0.74914518],
#        [0.91673976],
#        [0.80459886],
# ...

# %%
from scipy.stats import chi2_contingency

contingency_table=pd.crosstab(data['Region'],data['Happiness Rank'])
chi2,p,dof,frequency=chi2_contingency(contingency_table)
print("Chi-Square Test Results : ")
print('Chi-Sqaure Value : ',chi2)
print('P-Value : ',p)
print('Degrees of freedom: ',dof)
print('Frequency Distribution : ',frequency)
# Out:
# Chi-Square Test Results :
# Chi-Sqaure Value :  1415.3258620689655
# P-Value :  0.4107040079831256
# Degrees of freedom:  1404
# Frequency Distribution :  [[0.01265823 0.01265823 0.01265823 ... 0.01265823 0.01265823 0.01265823]
#  [0.1835443  0.1835443  0.1835443  ... 0.1835443  0.1835443  0.1835443 ]
#  [0.03797468 0.03797468 0.03797468 ... 0.03797468 0.03797468 0.03797468]
#  ...
#  [0.0443038  0.0443038  0.0443038  ... 0.0443038  0.0443038  0.0443038 ]
#  [0.25316456 0.25316456 0.25316456 ... 0.25316456 0.25316456 0.25316456]
#  [0.13291139 0.13291139 0.13291139 ... 0.13291139 0.13291139 0.13291139]]

# %% [markdown]
# Since our P-value for chi-sqaure test is more than 0.05, we reject our null hypothesis and conclude that there is a correlation between variables :  Region and Happiness Rank

# %%
covariance_matrix = np.cov(data[['Economy (GDP per Capita)','Health (Life Expectancy)']],rowvar=False)
covariance_matrix
# Out:
# array([[0.16250636, 0.08132299],
#        [0.08132299, 0.06104742]])

# %%
sns.heatmap(covariance_matrix,annot=True)
plt.xlabel('Economy (GDP per Capita)')
plt.ylabel('Health (Life Expectancy)')
plt.show()

# %%
bin = [0,4,5.5,8]
bin_label=['Happiness Score-Low','Happiness Score-Medium','Happiness Score-High']
happiness_counts=pd.cut(data['Happiness Score'],bins=bin,right=False).value_counts().sort_index()
plt.figure(figsize=(8,8))
plt.bar(bin_label,happiness_counts,color=['green','maroon','cyan'])
plt.show()

# %%
data['Health (Life Expectancy)'].plot(kind='hist',color='lightgreen')
plt.xlabel('Health Values')
plt.show()

# %%
bi = [0,4,5.5,8]
bi_label=['Region Score-Low','Region Score-Medium','Region Score-High']
counts_happiness=pd.cut(data['Happiness Score'],bins=bi,right=False).value_counts().sort_index()
plt.figure(figsize=(8,8))
plt.bar(bi_label,counts_happiness,color=['green','maroon','cyan'])
plt.show()
